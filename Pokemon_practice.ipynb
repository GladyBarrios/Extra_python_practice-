# %%
import pandas as pd

# %%
poke = pd.read_csv('pokemon_data.csv')
poke.head() #head is the top of the list 

#remeber if you dont specify the number in the () it will just give you the first 5
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
poke.tail() #this is the Bottom

# %%
#this is the same data but loaded with excel 

df_xlsx = pd.read_excel('pokemon_data.xlsx')
df_xlsx

# %%
#this is with the txt (tab seperated file) 

df = pd.read_csv('pokemon_data.txt', delimiter='\t')
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
## read the headders 
####df.columns

##read each column 
#df[['Name', 'Type 1', 'Attack']][0:5]

## read each row 
#df.iloc[1:4] ## iloc means integer location 

# this formats it diffrent 
#for index, row in df.iterrows():
    #print(index,row)

#this is condition statements 
df.loc[df['Type 1']== "Grass"]


## read a specific location (R,C)

#df.iloc[2,1]

# %%
#this is for stats 

df.describe()
# Out:
#                 #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750   69.258750   79.001250   73.842500   72.820000   71.902500
# std    208.343798   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.000000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    184.750000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    364.500000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    539.250000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    721.000000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# ...

# %%
df.sort_values('Name')#this will make it alphabetical
# Out:
#        #                     Name   Type 1  Type 2   HP  Attack  Defense  \
# 510  460                Abomasnow    Grass     Ice   90      92       75
# 511  460  AbomasnowMega Abomasnow    Grass     Ice   90     132      105
# 68    63                     Abra  Psychic     NaN   25      20       15
# 392  359                    Absol     Dark     NaN   65     130       60
# 393  359          AbsolMega Absol     Dark     NaN   65     150       60
# ..   ...                      ...      ...     ...  ...     ...      ...
# 632  571                  Zoroark     Dark     NaN   60     105       60
# 631  570                    Zorua     Dark     NaN   40      65       40
# 46    41                    Zubat   Poison  Flying   40      45       35
# 695  634                 Zweilous     Dark  Dragon   72      85       70
# 794  718         Zygarde50% Forme   Dragon  Ground  108     100      121
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df.sort_values(['Type 1','Name']) #this is for a list #acending for type 1 and lowest number to highest in name
# Out:
#        #                   Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 678  617               Accelgor    Bug     NaN   80      70       40      100
# 182  168                Ariados    Bug  Poison   70      90       70       60
# 290  267              Beautifly    Bug  Flying   60      70       50      100
# 18    15               Beedrill    Bug  Poison   65      90       40       45
# 19    15  BeedrillMega Beedrill    Bug  Poison   65     150       40       15
# ..   ...                    ...    ...     ...  ...     ...      ...      ...
# 351  321                Wailord  Water     NaN  170      90       45       90
# 10     8              Wartortle  Water     NaN   59      63       80       65
# 372  340               Whiscash  Water  Ground  110      78       73       76
# 301  278                Wingull  Water  Flying   40      30       30       55
# 209  194                 Wooper  Water  Ground   55      45       45       25
#
# ...

# %%
df.sort_values(['Type 1','Name'], ascending=[1,0])
# Out:
#        #                 Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 520  469              Yanmega    Bug  Flying   86      76       86      116
# 208  193                Yanma    Bug  Flying   65      65       45       75
# 288  265              Wurmple    Bug     NaN   45      45       35       20
# 460  413  WormadamTrash Cloak    Bug   Steel   60      69       95       69
# 459  413  WormadamSandy Cloak    Bug  Ground   60      79      105       59
# ..   ...                  ...    ...     ...  ...     ...      ...      ...
# 11     9            Blastoise  Water     NaN   79      83      100       85
# 610  550             Basculin  Water     NaN   70      92       65       80
# 371  339             Barboach  Water  Ground   50      48       43       46
# 199  184            Azumarill  Water   Fairy  100      50       80       60
# 655  594            Alomomola  Water     NaN  165      75       80       40
#
#      Sp. Def  Speed  Generation  Legendary
# ...

# %%
df.sort_values('Name', ascending=False) #not alphabetical
# Out:
#        #                     Name   Type 1  Type 2   HP  Attack  Defense  \
# 794  718         Zygarde50% Forme   Dragon  Ground  108     100      121
# 695  634                 Zweilous     Dark  Dragon   72      85       70
# 46    41                    Zubat   Poison  Flying   40      45       35
# 631  570                    Zorua     Dark     NaN   40      65       40
# 632  571                  Zoroark     Dark     NaN   60     105       60
# ..   ...                      ...      ...     ...  ...     ...      ...
# 393  359          AbsolMega Absol     Dark     NaN   65     150       60
# 392  359                    Absol     Dark     NaN   65     130       60
# 68    63                     Abra  Psychic     NaN   25      20       15
# 511  460  AbomasnowMega Abomasnow    Grass     Ice   90     132      105
# 510  460                Abomasnow    Grass     Ice   90      92       75
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
# adding the collum with the totals of all the stats

df['Total']= df['HP'] + df['Attack'] + df['Defense'] + df['Sp. Atk'] + df['Sp. Def'] + df['Speed']
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total
# 0         65       65     45           1      False    318
# ...

# %%
#always good to doube check the numbers

# %%
#another method

 #so the first : means all of the rows everythingkinda like [:], then [4:9], but itas all within one bracket 
df['Total2'] = df.iloc[:, 4:10].sum(axis=1)
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total  Total2
# ...

# %%
cols = list(df.columns)

df = df[cols[0:4] + [cols[-1]]+ cols[4:13]]
df
# Out:
#        #                   Name   Type 1  Type 2  Total2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison     318  45      49       49
# 1      2                Ivysaur    Grass  Poison     405  60      62       63
# 2      3               Venusaur    Grass  Poison     525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison     625  80     100      123
# 4      4             Charmander     Fire     NaN     309  39      52       43
# ..   ...                    ...      ...     ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy     600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy     700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost     600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark     680  80     160       60
# 799  721              Volcanion     Fire   Water     600  80     110      120
#
# ...

# %% [markdown]
# ## filering data

# %%
new_df= df.loc[(df['Type 1']== 'Grass')& (df['Type 2']=='Poison')& (df['HP']>70)] #and

new_df = new_df.reset_index()

new_df
# Out:
#    index    #                   Name Type 1  Type 2  Total2   HP  Attack  \
# 0      2    3               Venusaur  Grass  Poison     525   80      82
# 1      3    3  VenusaurMega Venusaur  Grass  Poison     625   80     100
# 2     50   45              Vileplume  Grass  Poison     490   75      80
# 3     77   71             Victreebel  Grass  Poison     490   80     105
# 4    652  591              Amoonguss  Grass  Poison     464  114      85
#
#    Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total
# 0       83      100      100     80           1      False    525
# 1      123      122      120     80           1      False    625
# 2       85      110       90     50           1      False    490
# 3       65      100       70     70           1      False    490
# 4       70       85       80     30           5      False    464

# %%
df.loc[(df['Type 1']== 'Grass')| (df['Type 2']=='Poison')] # or
# Out:
#        #                   Name Type 1    Type 2  Total2   HP  Attack  \
# 0      1              Bulbasaur  Grass    Poison     318   45      49
# 1      2                Ivysaur  Grass    Poison     405   60      62
# 2      3               Venusaur  Grass    Poison     525   80      82
# 3      3  VenusaurMega Venusaur  Grass    Poison     625   80     100
# 16    13                 Weedle    Bug    Poison     195   40      35
# ..   ...                    ...    ...       ...     ...  ...     ...
# 718  650                Chespin  Grass       NaN     313   56      61
# 719  651              Quilladin  Grass       NaN     405   61      78
# 720  652             Chesnaught  Grass  Fighting     530   88     107
# 740  672                 Skiddo  Grass       NaN     350   66      65
# 741  673                 Gogoat  Grass       NaN     531  123     100
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total
# ...

# %%
#looking at all the names that have MEGA 

df.loc[df['Name'].str.contains('Mega')]
# Out:
#        #                       Name    Type 1    Type 2  Total2   HP  Attack  \
# 3      3      VenusaurMega Venusaur     Grass    Poison     625   80     100
# 7      6  CharizardMega Charizard X      Fire    Dragon     634   78     130
# 8      6  CharizardMega Charizard Y      Fire    Flying     634   78     104
# 12     9    BlastoiseMega Blastoise     Water       NaN     630   79     103
# 19    15      BeedrillMega Beedrill       Bug    Poison     495   65     150
# 23    18        PidgeotMega Pidgeot    Normal    Flying     579   83      80
# 71    65      AlakazamMega Alakazam   Psychic       NaN     590   55      50
# 87    80        SlowbroMega Slowbro     Water   Psychic     590   95      75
# 102   94          GengarMega Gengar     Ghost    Poison     600   60      65
# 124  115  KangaskhanMega Kangaskhan    Normal       NaN     590  105     125
# 137  127          PinsirMega Pinsir       Bug    Flying     600   65     155
# ...

# %%
#dropping all the names that have mega 

df.loc[~df['Name'].str.contains('Mega')]
# Out:
#        #                 Name   Type 1  Type 2  Total2   HP  Attack  Defense  \
# 0      1            Bulbasaur    Grass  Poison     318   45      49       49
# 1      2              Ivysaur    Grass  Poison     405   60      62       63
# 2      3             Venusaur    Grass  Poison     525   80      82       83
# 4      4           Charmander     Fire     NaN     309   39      52       43
# 5      5           Charmeleon     Fire     NaN     405   58      64       58
# ..   ...                  ...      ...     ...     ...  ...     ...      ...
# 794  718     Zygarde50% Forme   Dragon  Ground     600  108     100      121
# 795  719              Diancie     Rock   Fairy     600   50     100      150
# 797  720  HoopaHoopa Confined  Psychic   Ghost     600   80     110       60
# 798  720   HoopaHoopa Unbound  Psychic    Dark     680   80     160       60
# 799  721            Volcanion     Fire   Water     600   80     110      120
#
# ...

# %%
import re
df.loc[df['Type 1'].str.contains('Fire|Grass', regex=True)]
# Out:
#        #                   Name Type 1  Type 2  Total2   HP  Attack  Defense  \
# 0      1              Bulbasaur  Grass  Poison     318   45      49       49
# 1      2                Ivysaur  Grass  Poison     405   60      62       63
# 2      3               Venusaur  Grass  Poison     525   80      82       83
# 3      3  VenusaurMega Venusaur  Grass  Poison     625   80     100      123
# 4      4             Charmander   Fire     NaN     309   39      52       43
# ..   ...                    ...    ...     ...     ...  ...     ...      ...
# 735  667                 Litleo   Fire  Normal     369   62      50       58
# 736  668                 Pyroar   Fire  Normal     507   86      68       72
# 740  672                 Skiddo  Grass     NaN     350   66      65       48
# 741  673                 Gogoat  Grass     NaN     531  123     100       62
# 799  721              Volcanion   Fire   Water     600   80     110      120
#
# ...

# %%
df.loc[df['Name'].str.contains('Pi[a-z]*', regex=True)]

#this is to find a certain name that starts with
# Out:
#        #                     Name    Type 1    Type 2  Total2   HP  Attack  \
# 20    16                   Pidgey    Normal    Flying     251   40      45
# 21    17                Pidgeotto    Normal    Flying     349   63      60
# 22    18                  Pidgeot    Normal    Flying     479   83      80
# 23    18      PidgeotMega Pidgeot    Normal    Flying     579   83      80
# 30    25                  Pikachu  Electric       NaN     320   35      55
# 136  127                   Pinsir       Bug       NaN     500   65     125
# 137  127        PinsirMega Pinsir       Bug    Flying     600   65     155
# 186  172                    Pichu  Electric       NaN     205   20      40
# 219  204                   Pineco       Bug       NaN     290   50      65
# 239  221                Piloswine       Ice    Ground     450  100     100
# 438  393                   Piplup     Water       NaN     314   53      51
# ...

# %% [markdown]
# # conditional chages

# %%
df.loc[df['Type 1'] == 'Fire', 'Type 1']= 'Flamer'

df
# Out:
#        #                   Name   Type 1  Type 2  Total2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison     318  45      49       49
# 1      2                Ivysaur    Grass  Poison     405  60      62       63
# 2      3               Venusaur    Grass  Poison     525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison     625  80     100      123
# 4      4             Charmander   Flamer     NaN     309  39      52       43
# ..   ...                    ...      ...     ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy     600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy     700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost     600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark     680  80     160       60
# 799  721              Volcanion   Flamer   Water     600  80     110      120
#
# ...

# %% [markdown]
# ## Aggregate Statistics (Group by)

# %%
df.groupby(['Type 1']).mean()
# Out:
#                    #      Total2         HP      Attack     Defense  \
# Type 1
# Bug       334.492754  378.927536  56.884058   70.971014   70.724638
# Dark      461.354839  445.741935  66.806452   88.387097   70.225806
# Dragon    474.375000  550.531250  83.312500  112.125000   86.375000
# Electric  363.500000  443.409091  59.795455   69.090909   66.295455
# Fairy     449.529412  413.176471  74.117647   61.529412   65.705882
# Fighting  363.851852  416.444444  69.851852   96.777778   65.925926
# Flamer    327.403846  458.076923  69.903846   84.769231   67.769231
# Flying    677.750000  485.000000  70.750000   78.750000   66.250000
# Ghost     486.500000  439.562500  64.437500   73.781250   81.187500
# Grass     344.871429  421.142857  67.271429   73.214286   70.800000
# Ground    356.281250  437.500000  73.781250   95.750000   84.843750
# Ice       423.541667  433.458333  72.000000   72.750000   71.416667
# Normal    319.173469  401.683673  77.275510   73.469388   59.846939
# ...
